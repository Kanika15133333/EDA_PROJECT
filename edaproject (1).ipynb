# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\kanik\OneDrive\Documents\Sales.csv")
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1                 NaN                                     NaN
# 2      04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# 3      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 4      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# ...               ...                                     ...
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215
#
# [18383 rows x 6 columns]

# %%
df.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
# 6   176562        USB-C Charging Cable                1      11.95
# 7   176563  Bose SoundSport Headphones                1      99.99
# 8   176564        USB-C Charging Cable                1      11.95
# 9   176565          Macbook Pro Laptop                1       1700
#
#        Order Date                        Purchase Address
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1             NaN                                     NaN
# 2  04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27       333 8th St, Los Angeles, CA 90001
# 6  04/29/19 13:03  381 Wilson St, San Francisco, CA 94016
# 7  04/02/19 07:46        668 Center St, Seattle, WA 98101
# 8  04/12/19 10:58         790 Ridge St, Atlanta, GA 30301
# 9  04/24/19 10:38  915 Willow St, San Francisco, CA 94016

# %%
df.tail(10)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 18373   194085          Wired Headphones                1      11.99
# 18374   194086              Google Phone                1        600
# 18375   194087      USB-C Charging Cable                2      11.95
# 18376   194088    AAA Batteries (4-pack)                2       2.99
# 18377   194089      USB-C Charging Cable                1      11.95
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 18373  04/17/19 20:12      315 12th St, Los Angeles, CA 90001
# 18374  04/28/19 08:50   981 Dogwood St, Los Angeles, CA 90001
# 18375  04/26/19 11:44          35 13th St, Portland, OR 97035
# 18376  04/04/19 18:46           718 12th St, Austin, TX 73301
# 18377  04/09/19 17:15    458 11th St, San Francisco, CA 94016
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215

# %%
df.info
# Out:
# <bound method DataFrame.info of       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1                 NaN                                     NaN
# 2      04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# 3      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 4      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# ...               ...                                     ...
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215
#
# [18383 rows x 6 columns]>

# %%
df.isna().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address    59
# dtype: int64

# %%
import pandas as pd 
nan_df = df[df.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    18268
# True        56
# Name: count, dtype: int64

# %%
dfa=df.drop_duplicates(subset=None, keep='first',inplace=False)
dfa
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001
# 2      04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# 3      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 4      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 5      04/30/19 09:27       333 8th St, Los Angeles, CA 90001
# ...               ...                                     ...
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215
#
# [18268 rows x 6 columns]

# %%
dfa.columns= ['order_ID' , 'Product', 'Quantity_Ordered' , 'Price_Each', 'Order_Date', 'Purchase_Address']
dfa.head()
# Out:
#   order_ID                     Product Quantity_Ordered Price_Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order_Date                      Purchase_Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
dfa['Date'] = dfa['Order_Date'].str[0:8]
dfa
# Out:
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\742200691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Date'] = dfa['Order_Date'].str[0:8]
#       order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order_Date                        Purchase_Address      Date
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001  04/19/19
# 2      04/07/19 22:30       682 Chestnut St, Boston, MA 02215  04/07/19
# 3      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19
# 4      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19
# 5      04/30/19 09:27       333 8th St, Los Angeles, CA 90001  04/30/19
# ...               ...                                     ...       ...
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001  04/08/19
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301  04/15/19
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016  04/28/19
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035  04/14/19
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215  04/18/19
#
# [18268 rows x 7 columns]

# %%
dfa['Month'] = dfa['Order_Date'].str[0:2]
dfa
# Out:
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\518384576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Month'] = dfa['Order_Date'].str[0:2]
#       order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order_Date                        Purchase_Address      Date Month
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001  04/19/19    04
# 2      04/07/19 22:30       682 Chestnut St, Boston, MA 02215  04/07/19    04
# 3      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 4      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 5      04/30/19 09:27       333 8th St, Los Angeles, CA 90001  04/30/19    04
# ...               ...                                     ...       ...   ...
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001  04/08/19    04
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301  04/15/19    04
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016  04/28/19    04
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035  04/14/19    04
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215  04/18/19    04
#
# [18268 rows x 8 columns]

# %%
dfa[['House_No. ','City','Pin_Code']] = dfa.Purchase_Address.str.split(",",expand=True)
dfa
# Out:
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\857950382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa[['House_No. ','City','Pin_Code']] = dfa.Purchase_Address.str.split(",",expand=True)
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\857950382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa[['House_No. ','City','Pin_Code']] = dfa.Purchase_Address.str.split(",",expand=True)
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\857950382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa[['House_No. ','City','Pin_Code']] = dfa.Purchase_Address.str.split(",",expand=True)
#       order_ID                     Product Quantity_Ordered Price_Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order_Date                        Purchase_Address      Date Month  \
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001  04/19/19    04
# 2      04/07/19 22:30       682 Chestnut St, Boston, MA 02215  04/07/19    04
# 3      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 4      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 5      04/30/19 09:27       333 8th St, Los Angeles, CA 90001  04/30/19    04
# ...               ...                                     ...       ...   ...
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001  04/08/19    04
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301  04/15/19    04
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016  04/28/19    04
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035  04/14/19    04
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215  04/18/19    04
#
#             House_No.             City   Pin_Code
# 0           917 1st St          Dallas   TX 75001
# 2      682 Chestnut St          Boston   MA 02215
# 3        669 Spruce St     Los Angeles   CA 90001
# 4        669 Spruce St     Los Angeles   CA 90001
# 5           333 8th St     Los Angeles   CA 90001
# ...                ...             ...        ...
# 18378   177 Jackson St     Los Angeles   CA 90001
# 18379    311 Forest St          Austin   TX 73301
# 18380    347 Sunset St   San Francisco   CA 94016
# 18381      835 Lake St        Portland   OR 97035
# 18382     354 North St          Boston   MA 02215
#
# [18268 rows x 11 columns]

# %%
dfa.Month.value_counts()
# Out:
# Month
# 04    18239
# 05       28
# Or        1
# Name: count, dtype: int64

# %%
dfa = dfa[dfa['Month'].str[:2]  != 'Or' ]
dfa.head()
# Out:
#   order_ID                     Product Quantity_Ordered Price_Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order_Date                      Purchase_Address      Date Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001  04/19/19    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215  04/07/19    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  04/12/19    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001  04/30/19    04
#
#         House_No.           City   Pin_Code
# 0       917 1st St        Dallas   TX 75001
# 2  682 Chestnut St        Boston   MA 02215
# 3    669 Spruce St   Los Angeles   CA 90001
# 4    669 Spruce St   Los Angeles   CA 90001
# 5       333 8th St   Los Angeles   CA 90001

# %%
dfa.shape
# Out:
# (18267, 11)

# %%
dfa['Month'] = dfa['Month'].astype('int64')
dfa['order_Date'] = pd.to_datetime(dfa['Order_Date'])
dfa['Date'] = pd.to_datetime(dfa['Date'])
dfa.info()
# Out:
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3729835466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Month'] = dfa['Month'].astype('int64')
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3729835466.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dfa['order_Date'] = pd.to_datetime(dfa['Order_Date'])
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_ID          18267 non-null  object
#  1   Product           18267 non-null  object
#  2   Quantity_Ordered  18267 non-null  object
#  3   Price_Each        18267 non-null  object
#  4   Order_Date        18267 non-null  object
#  5   Purchase_Address  18267 non-null  object
#  6   Date              18267 non-null  datetime64[ns]
#  7   Month             18267 non-null  int64
#  8   House_No.         18267 non-null  object
#  9   City              18267 non-null  object
#  10  Pin_Code          18267 non-null  object
#  11  order_Date        18267 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(9)
# memory usage: 1.8+ MB
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3729835466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['order_Date'] = pd.to_datetime(dfa['Order_Date'])
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3729835466.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dfa['Date'] = pd.to_datetime(dfa['Date'])
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3729835466.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Date'] = pd.to_datetime(dfa['Date'])

# %%
dfa.order_ID.value_counts()
# Out:
# order_ID
# 193511    4
# 192645    3
# 191742    3
# 188881    3
# 176797    3
#          ..
# 194082    1
# 194083    1
# 194084    1
# 194085    1
# 194086    1
# Name: count, Length: 17537, dtype: int64

# %%
dfa.Quantity_Ordered.value_counts()
# Out:
# Quantity_Ordered
# 1    16536
# 2     1328
# 3      299
# 4       72
# 5       24
# 6        7
# 7        1
# Name: count, dtype: int64

# %%
dfa['Quantity_Ordered'] = dfa['Quantity_Ordered'].astype('int32')
dfa['Price_Each'] = dfa['Price_Each'].astype('float64')
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_ID          18267 non-null  object
#  1   Product           18267 non-null  object
#  2   Quantity_Ordered  18267 non-null  int32
#  3   Price_Each        18267 non-null  float64
#  4   Order_Date        18267 non-null  object
#  5   Purchase_Address  18267 non-null  object
#  6   Date              18267 non-null  datetime64[ns]
#  7   Month             18267 non-null  int64
#  8   House_No.         18267 non-null  object
#  9   City              18267 non-null  object
#  10  Pin_Code          18267 non-null  object
#  11  order_Date        18267 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int32(1), int64(1), object(7)
# memory usage: 1.7+ MB
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\1175309672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Quantity_Ordered'] = dfa['Quantity_Ordered'].astype('int32')
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\1175309672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Price_Each'] = dfa['Price_Each'].astype('float64')

# %%
dfa['Sales'] = dfa['Quantity_Ordered'] *dfa['Price_Each']
dfa
# Out:
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\4175145487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Sales'] = dfa['Quantity_Ordered'] *dfa['Price_Each']
#       order_ID                     Product  Quantity_Ordered  Price_Each  \
# 0       176558        USB-C Charging Cable                 2       11.95
# 2       176559  Bose SoundSport Headphones                 1       99.99
# 3       176560                Google Phone                 1      600.00
# 4       176560            Wired Headphones                 1       11.99
# 5       176561            Wired Headphones                 1       11.99
# ...        ...                         ...               ...         ...
# 18378   194090                Google Phone                 1      600.00
# 18379   194091       AA Batteries (4-pack)                 1        3.84
# 18380   194092      AAA Batteries (4-pack)                 2        2.99
# 18381   194093       AA Batteries (4-pack)                 1        3.84
# 18382   194094    Lightning Charging Cable                 1       14.95
#
#            Order_Date                        Purchase_Address       Date  \
# 0      04/19/19 08:46            917 1st St, Dallas, TX 75001 2019-04-19
# 2      04/07/19 22:30       682 Chestnut St, Boston, MA 02215 2019-04-07
# 3      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001 2019-04-12
# 4      04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001 2019-04-12
# 5      04/30/19 09:27       333 8th St, Los Angeles, CA 90001 2019-04-30
# ...               ...                                     ...        ...
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001 2019-04-08
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301 2019-04-15
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016 2019-04-28
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035 2019-04-14
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215 2019-04-18
#
#        Month       House_No.             City   Pin_Code          order_Date  \
# 0          4       917 1st St          Dallas   TX 75001 2019-04-19 08:46:00
# 2          4  682 Chestnut St          Boston   MA 02215 2019-04-07 22:30:00
# 3          4    669 Spruce St     Los Angeles   CA 90001 2019-04-12 14:38:00
# 4          4    669 Spruce St     Los Angeles   CA 90001 2019-04-12 14:38:00
# 5          4       333 8th St     Los Angeles   CA 90001 2019-04-30 09:27:00
# ...      ...              ...             ...        ...                 ...
# 18378      4   177 Jackson St     Los Angeles   CA 90001 2019-04-08 17:11:00
# 18379      4    311 Forest St          Austin   TX 73301 2019-04-15 16:02:00
# 18380      4    347 Sunset St   San Francisco   CA 94016 2019-04-28 14:36:00
# 18381      4      835 Lake St        Portland   OR 97035 2019-04-14 15:09:00
# 18382      4     354 North St          Boston   MA 02215 2019-04-18 11:08:00
#
#         Sales
# 0       23.90
# 2       99.99
# 3      600.00
# 4       11.99
# 5       11.99
# ...       ...
# 18378  600.00
# 18379    3.84
# 18380    5.98
# 18381    3.84
# 18382   14.95
#
# [18267 rows x 13 columns]

# %%
#sales Values
Monthly_sales = dfa.groupby('Month').Sales.sum()
Monthly_sales
# Out:
# Month
# 4    3384047.56
# 5      10559.29
# Name: Sales, dtype: float64

# %%
city_sales=dfa.City.value_counts()
city_sales
# Out:
# City
# San Francisco    4434
# Los Angeles      3021
# New York City    2429
# Boston           1915
# Atlanta          1470
# Seattle          1440
# Dallas           1348
# Portland         1237
# Austin            973
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,6))
sns.countplot(x = dfa['City'])
plt.xlabel("City Name")
plt.ylabel("Number pf sells")
plt.title("city vs sales")
# Out:
# Text(0.5, 1.0, 'city vs sales')

# %%
dfa['Order_Date'] = pd.to_datetime(dfa['Order_Date'], errors='coerce')
dfa['Hour'] = dfa['Order_Date'].dt.hour
# Out:
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3372713952.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dfa['Order_Date'] = pd.to_datetime(dfa['Order_Date'], errors='coerce')
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3372713952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Order_Date'] = pd.to_datetime(dfa['Order_Date'], errors='coerce')
# C:\Users\kanik\AppData\Local\Temp\ipykernel_19836\3372713952.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['Hour'] = dfa['Order_Date'].dt.hour

# %%
hours = [hour for hour, dfa in dfa.groupby('Hour')]
plt.plot(hours, dfa.groupby('Hour').count())
plt.grid(True)
plt.xticks(hours)
plt.xlabel('Hours in 24 Hr Format')
plt.ylabel('Orders')
plt.show()

# %%
Highest_orders = dfa.Product.value_counts() 
Highest_sales = dfa.groupby('Product').Sales.sum().sort_values(ascending=False)

fig, axes = plt.subplots(1, 2, figsize=(20,7))
sns.barplot(ax=axes[0],x=Highest_orders.index, y=Highest_orders.values)
axes[0].set_xlabel('Products')
axes[0].set_ylabel('No. of orders')
axes[1].tick_params(axis = 'x' , rotation=90)

sns.barplot(ax=axes[1],x=Highest_sales.index, y=Highest_sales.values)
axes[1].set_xlabel('product')
axes[1].set_ylabel('Sales Amount')
axes[1].tick_params(axis='x',rotation=90)
plt.show()
